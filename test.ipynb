# %%
# Import the module
from lstm_forecasting import train_and_evaluate
import pandas as pd

# %%
# Define your symbol target and dataframe
symbol_target = "BNB/USDT"
new_df = pd.read_parquet('data/merged_crypto_data.parquet')
  # Replace this with your actual dataframe

# Call the function
model, scaler = train_and_evaluate(new_df, symbol_target)
# Out:
# Epoch [1/2], Loss: 0.6885
# Epoch [2/2], Loss: 0.6853
# Test Accuracy: 77.57%
# Accuracy: 0.7766
# F1-Score: 0.6789
